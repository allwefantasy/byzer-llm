# %%
import byzerllm
import json
import base64

llm = byzerllm.ByzerLLM.from_default_model("openai_image_gen")
t = llm.chat_oai(conversations=[{
    "role":"user",
    "content": json.dumps({
        "input":"a white siamese cat",
        "size": "1024x1024",
        "quality": "standard"
    },ensure_ascii=False)
}])

with open("output1.jpg","wb") as f:
    f.write(base64.b64decode(t[0].output))

import matplotlib.pyplot as plt

image_path = "output1.jpg"
image = plt.imread(image_path)

plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# 2024-07-29 21:26:42.409 | INFO     | byzerllm.utils.connect_ray:connect_cluster:48 - JDK 21 will be used (/Users/allwefantasy/.auto-coder/jdk-21.0.2.jdk/Contents/Home)...
# 2024-07-29 21:26:42,477	INFO worker.py:1564 -- Connecting to existing Ray cluster at address: 127.0.0.1:6379...
# 2024-07-29 21:26:42,478	INFO worker.py:1582 -- Calling ray.init() again after it has already been called.

# %%
# !byzerllm deploy --pretrained_model_type saas/openai \
--cpus_per_worker 0.001 \
--gpus_per_worker 0 \
--num_workers 1 \
--infer_params saas.api_key=${MODEL_OPENAI_TOKEN} saas.model=dall-e-3 \
--model openai_image_gen
# Out:
# Command Line Arguments:
# --------------------------------------------------
# command             : deploy
# ray_address         : auto
# num_workers         : 1
# worker_concurrency  : 1
# gpus_per_worker     : 0.0
# cpus_per_worker     : 0.001
# model_path          :
# pretrained_model_type: saas/openai
# model               : openai_image_gen
# infer_backend       :
# infer_params        : {'saas.api_key': '******', 'saas.model': 'dall-e-3'}
# file                : None
# --------------------------------------------------
# ✓ Ray is already runningatus...0m
# ⠋ Checking Ray status...
# 2024-07-29 21:25:49.939 | INFO     | byzerllm.utils.connect_ray:connect_cluster:48 - JDK 21 will be used (/Users/allwefantasy/.auto-coder/jdk-21.0.2.jdk/Contents/Home)...
# 2024-07-29 21:25:50,009	INFO worker.py:1564 -- Connecting to existing Ray cluster at address: 127.0.0.1:6379...
# 2024-07-29 21:25:50,022	INFO worker.py:1740 -- Connected to Ray cluster. View the dashboard at 127.0.0.1:8265
# Failed to look up actor with name 'openai_image_gen'. This could because 1. You are trying to look up a named actor you didn't create. 2. The named actor died. 3. You did not use a namespace matching the namespace of the actor.
# 模型 openai_image_gen 部署成功
