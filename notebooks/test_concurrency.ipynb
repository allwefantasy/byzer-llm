# %%
import byzerllm
from concurrent.futures import ThreadPoolExecutor
import time

llm = byzerllm.ByzerLLM.from_default_model(model="deepseek_chat")

@byzerllm.prompt()
def hello(name: str) -> str:
    '''
    你好, {{ name }}
    '''

def call_hello(name):
    start_time = time.time()
    llm = byzerllm.ByzerLLM()
    llm.setup_default_model_name("deepseek_chat")
    result = hello.with_llm(llm).run(name=name)
    end_time = time.time()
    return f"Result for {name}: {result}\nTime taken: {end_time - start_time:.2f} seconds\n"

names = ["Alice", "Bob", "Charlie", "David", "Eve"] * 1000

with ThreadPoolExecutor(max_workers=800) as executor:
    results = list(executor.map(call_hello, names))

for result in results:
    print(result)
# Out:
# 2024-09-04 15:01:40.170 | INFO     | byzerllm.utils.connect_ray:connect_cluster:48 - JDK 21 will be used (/Users/allwefantasy/.auto-coder/jdk-21.0.2.jdk/Contents/Home)...
# 2024-09-04 15:01:40,219	INFO worker.py:1564 -- Connecting to existing Ray cluster at address: 127.0.0.1:6379...
# 2024-09-04 15:01:40,233	INFO worker.py:1740 -- Connected to Ray cluster. View the dashboard at 127.0.0.1:8265
# Result for Alice: 你好！有什么我可以帮助你的吗？
# Time taken: 11.87 seconds
#
# Result for Bob: Hello! How can I assist you today?
# Time taken: 5.31 seconds
#
# Result for Charlie: Hello! How can I assist you today?
# Time taken: 4.67 seconds
#
# Result for David: Hello! How can I assist you today?
# Time taken: 5.23 seconds
#
# Result for Eve: 你好！有什么我可以帮助你的吗？
# Time taken: 5.29 seconds
#
# Result for Alice: 你好！有什么我可以帮助你的吗？
# Time taken: 4.47 seconds
#
# Result for Bob: 你好，Bob！有什么我可以帮助你的吗？
# Time taken: 5.93 seconds
#
# Result for Charlie: 你好，Charlie！有什么我可以帮助你的吗？
# Time taken: 11.43 seconds
#
# ...
